# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\basim\My_project\lab\homeprices.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\basim\AppData\Local\Temp\ipykernel_6256\2924964316.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv('C:\\Users\\basim\My_project\lab\homeprices.csv')
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('area')
plt.ylabel('Price')
plt.scatter(df.area,df.price,color='red',marker='+')

# %%
df.isnull().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
x=df.drop('price',axis='columns')
y=df.price

# %%
reg = linear_model.LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
reg.predict([[36]])
# Out:
# C:\Users\basim\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([185504.79452055])
